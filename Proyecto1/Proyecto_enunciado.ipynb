# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # **Proyecto 1 - MDS7202 Laboratorio de Programación Científica para Ciencia de Datos 📚**
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# *Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir.*
#
# ### Equipo:
#
# - Nicolás Ojeda G.
# - Eduardo Moya B.
#
#
# ### **Link de repositorio de GitHub:** [https://github.com/eduardomoyab/MDS7202_1](https://github.com/eduardomoyab/MDS7202_1)
#
# Fecha límite de entrega 📆: 10 de Noviembre de 2023.

# %% [markdown]
# ----
#
# ## Reglas
#
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://worldskateamerica.org/wp-content/uploads/2023/07/SANTIAGO-2023-1-768x153.jpg" alt="Descripción de la imagen">
# </div>
#
# En un Chile azotado por un profundo caos político-económico y el resurgimiento de programas de televisión de dudosa calidad, todas las miradas y esperanzas son depositadas en el éxito de un único evento: Santiago 2023. La nación necesitaba desesperadamente un respiro, y los Juegos de Santiago 2023 prometían ser una luz al final del túnel.
#
# El Presidente de la República -conocido en las calles como Bombín-, consciente de la importancia de este evento para la revitalización del país, decide convocar a usted y su equipo en calidad de expertos en análisis de datos y estadísticas. Con gran solemnidad, el presidente les encomienda una importante y peligrosa: liderar un proyecto que permitiera caracterizar de forma automática y eficiente los datos generados por estos magnos juegos. Para esto, el presidente le destaca que la solución debe considerar los siguientes puntos:
# - Caracterización automática de los datos
# - La solución debe ser compatible con cualquier dataset
# - Se les facilita el dataset *olimpiadas.parquet*, el cual recopila data de diferentes juegos olímpicos realizados en los últimos años

# %% [markdown]
# ## 1.1 Creación de `Profiler` Class (4.0 puntos)
#
# Cree la clase `Profiler`. Como mínimo, esta debe tener las siguientes funcionalidades:
#
# 1. El método constructor, el cual debe recibir los datos a procesar en formato `Pandas DataFrame`. Además, este método debe generar una carpeta en su directorio de trabajo con el nombre `EDA_fecha`, donde `fecha` corresponda a la fecha de ejecución en formato `DD-MM-YYYY`.
#
# 2. El método `summarize`, el cual debe caracterizar las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Reportar el tipo de variable
#     - Reportar el número y/o porcentaje de valores únicos de la variable
#     - Reportar el número y/o porcentaje de valores nulos
#     - Si la variables es numérica:
#         - Reportar el número y/o porcentaje de valores cero, negativos y outliers
#         - Reportar estadística descriptiva como el valor mínimo, máximo, promedio y los percentiles 25, 50, 75 y 100
#    - Levantar una alerta en caso de encontrar alguna anomalía fuera de lo común (el criterio debe ser ajustable por el usuario)
#    - Guardar sus resultados en el directorio `EDA_fecha/summary.txt`. El archivo debe separar de forma clara y ordenada los resultados de cada punto.
#
# 3. El método `plot_vars`, el cual debe graficar la distribución e interraciones de las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/plots`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Para las variables numéricas:
#         - Genere un gráfico de distribución de densidad
#         - Grafique la correlación entre las variables
#     - Para las variables categóricas:
#         - Genere un histograma de las top N categorías (N debe ser un parámetro ajustable)
#         - Grafique el coeficiente V de Cramer entre las variables
#     - Guardar cada gráfico generado en la carpeta `EDA_fecha/plots` en formato `.pdf` y bajo el naming `variable.pdf`, donde `variable` es el nombre de la variable de interés
#
# 4. El método `clean_data`, el cual debe limpiar los datos para que luego puedan ser procesados. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clean_data`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Drop de valores duplicados
#     - Implementar como mínimo 2 técnicas para tratar los valores nulos, como:
#         - Drop de valores nulos
#         - Imputar valores nulos con alguna técnica de imputación
#         - Funcionalidad para escoger entre una técnica y la otra.
#     - Una de las columnas del dataframe presenta datos *no atómicos*. Separe dicha columna en las columnas que la compongan.
#         - Hint: ¿Qué caracteres permiten separar una columna de otra?
#         - Para las pruebas con el dataset nuevo, puede esperar que exista al menos una columna con este tipo de problema. Asuma que los separadores serán los mismos, aunque el número de columnas a separar puede ser distinto.
#     - Deberían usar `FunctionTransformer`.
#     - Guardar los datos procesados en formato `.csv` en el path `EDA_fecha/clean_data/data.csv`
#
# 5. El método `scale`, el cual debe preparar adecuadamente los datos para luego ser consumidos por algún tipo de algoritmo. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/scale`
#     - Procesar de forma adecuada los datos numéricos y categóricos:
#         - Su método debe recibir las técnicas de escalamiento como argumento de entrada (utilizar solo técnicas compatibles con el framework de `sklearn`)
#         - Para los atributos numéricos, se transforme los datos con un escalador logarítmico y un `MinMaxScaler`
#         - Asuma que no existen datos ordinales en su dataset
#     - Guardar todo este procesamiento en un `ColumnTransformer`.
#     - Guardar los datos limpios y transformados en formato `.csv` en el path `EDA_fecha/process/scaled_features.csv`
#
# 6. El método `make_clusters`, el cual debe generar clusters de los datos usando algún algoritmo de clusterización. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clusters`
#     - Generar un estudio del codo donde señale la cantidad de clusters optimos para el desarrollo.
#     - Su método debe recibir el algoritmo de clustering como argumento de entrada (utilizar solo algoritmos compatibles con el framework de `sklearn`).
#     - No olvide pre procesar adecuadamente los datos antes de implementar la técnica de clustering.
#     - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#     - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#     - Una vez generado los clusters, proyecte los datos a 2 dimensiones usando su técnica de reducción de dimensionalidad favorita y grafique los resultados coloreando por cluster.
#     - Guardar los datos con su respectivo cluster en formato `.csv` en el path `EDA_fecha/clusters/data_clusters.csv`. Guarde también los gráficos generados en el mismo path.
#
# 7. El método `detect_anomalies`, el cual debe detectar anomalías en los datos. Como mínimo, se espera que su método pueda:
#
#     - Crear la carpeta `EDA_fecha/anomalies`
#     - Implementar alguna técnica de detección de anomalías.
#     - Al igual que el punto anterior, su método debe considerar los siguientes puntos:
#         - No olvide pre procesar de forma adecuada los datos antes de implementar la técnica de detección de anomalía.
#         - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#         - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#         - Su método debe recibir el algoritmo como argumento de entrada
#         - Una vez generado las etiquetas, proyecte los datos a 2 dimensiones y grafique los resultados coloreando por las etiquetas predichas por el detector de anomalías
#     - Guardar los datos con su respectiva etiqueta en formato `.csv` en el path `EDA_fecha/anomalies/data_anomalies.csv`. Guarde también los gráficos generados en el mismo path.
#
# 8. El método `profile`, el cual debe ejecutar todos los métodos anteriores.
#
# 9. Crear el método `clearGarbage` para eliminar las carpetas/archivos creados/as por la clase `Profiler`.
#
# Algunas consideraciones generales:
# - Su clase será testeada con datos tabulares diferentes a los provistos. No desarrollen código *hardcodeado*: su clase debe ser capaz de funcionar para **cualquier** dataset.
# - Aplique todo su conocimiento sobre buenas prácticas de programación: se evaluará que su código sea limpio y ordenado.
# - Recuerden documentar cada una de las funcionalidades que implementen.
# - Recuerden adjuntar sus `requirements.txt` junto a su entrega de proyecto. **El código que no se pueda ejecutar por imcompatibilidades de librerías no será corregido.**

# %% [markdown]
# Cargamos algunas librerías

# %%
import os
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import FunctionTransformer, MinMaxScaler, LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.ensemble import IsolationForest
from scipy.stats import chi2_contingency
from yellowbrick.cluster import KElbowVisualizer
from kmodes.kmodes import KModes
import shutil
import re

# %%
data = pd.read_parquet('olimpiadas.parquet')
data
# Out:
#             ID                      Name Sex            Team  NOC
# 0            1                 A Dijiang   M           China  CHN  \
# 1            2                  A Lamusi   M           China  CHN
# 2            3       Gunnar Nielsen Aaby   M         Denmark  DEN
# 3            4      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN
# 4            5  Christine Jacoba Aaftink   F     Netherlands  NED
# ...        ...                       ...  ..             ...  ...
# 271111  135569                Andrzej ya   M        Poland-1  POL
# 271112  135570                  Piotr ya   M          Poland  POL
# 271113  135570                  Piotr ya   M          Poland  POL
# 271114  135571        Tomasz Ireneusz ya   M          Poland  POL
# 271115  135571        Tomasz Ireneusz ya   M          Poland  POL
#
#               Games  Year  Season            City          Sport
# 0       1992 Summer  1992  Summer       Barcelona     Basketball  \
# ...

# %%
class Profiler():
        
    #paso 1: definir el constructor
    def __init__(self, data): 
        """
        Inicializa la clase Profiler.

        Parámetros:
        data (pandas.DataFrame): El conjunto de datos de entrada para el análisis.
        """
        self.data = data
        self.timestamp = datetime.datetime.now().strftime("%d-%m-%Y")
        self.output_dir = f"EDA_{self.timestamp}"
        os.makedirs(self.output_dir, exist_ok=True)
        self.cleaned = False
        self.scaled = False
        self.data_cruda = data.copy()

    #paso 2: definir summarise
    def summarize(self, variables=None, na_threshold=0.1, outlier_threshold=0.1, unique_threshold=200,view = False):
        """
        Genera un informe resumido del conjunto de datos.

        Parámetros:
        variables (lista, opcional): La lista de variables a resumir.
        na_threshold (float, opcional): El umbral para valores faltantes.
        outlier_threshold (float, opcional): El umbral para detectar valores atípicos.
        unique_threshold (int, opcional): El umbral para la cantidad de valores únicos en variables categóricas.
        view (bool, opcional): Si es True, muestra el informe resumido.
        """
        if variables is None:
            variables = self.data.columns

        summary_file = os.path.join(self.output_dir, "summary.txt")
        with open(summary_file, "w") as f:
            for var in variables:
                var_data = self.data[var]
                f.write(f"Variable: {var}\n")
                f.write(f"Tipo Variable: {var_data.dtype}\n")
                f.write(f"Valores Unicos: {var_data.nunique()}\n")
                f.write(f"Porcentaje de Valores Faltantes: {var_data.isnull().mean() * 100:.2f}%\n")

                if pd.api.types.is_numeric_dtype(var_data):
                    f.write(f"Numero de Ceros: {np.sum(var_data == 0)}\n")
                    f.write(f"Número de Valores Negativos: {np.sum(var_data < 0)}\n")
                    outliers = np.abs(var_data - var_data.mean()) > 3 * var_data.std()
                    f.write(f"Número de Outliers: {np.sum(outliers)}\n")
                    f.write(f"Min: {var_data.min()}\n")
                    f.write(f"Max: {var_data.max()}\n")
                    f.write(f"Promedio: {var_data.mean()}\n")
                    percentiles = var_data.quantile([0.25, 0.5, 0.75, 1])
                    f.write(f"Percentiles: {percentiles}\n")
                    
                    if (var_data.isna().mean() > na_threshold) or (outliers.mean() > outlier_threshold):
                        f.write("Anomalía Detectada!\n")
                        if var_data.isna().mean() > na_threshold:
                            f.write(f"Tipo de Anomalia: Alto Porcentaje de Valores Faltantes\n")
                        if outliers.mean() > outlier_threshold:
                            f.write(f"Tipo de Anomalia: Alto Porcentaje de Outliers\n")

                else:
                    # Alerta de alta cardinalidad
                    if var_data.nunique() > unique_threshold:
                        f.write("Anomalia Detectada! Alto Numero de Valores Unicos\n")
                        f.write(f"Tipo de Anomalia: Alta Cardinalidad (Valores Unicos: {var_data.nunique()})\n")


                f.write("\n")
        #Si view es True, se imprime en pantalla el contenido de summary
        if view:
            with open(summary_file, "r") as f:
                print(f.read())


    def plot_vars(self, variables=None, top_categories=15):
        """
        Genera gráficos para variables numéricas y categóricas.

        Parámetros:
        variables (lista, opcional): La lista de variables a graficar.
        top_categories (int, opcional): Número de categorías principales a mostrar para variables categóricas.
        """
        categorical_variables = []
        if variables is None:
            variables = self.data.columns

        plots_dir = os.path.join(self.output_dir, "plots")
        os.makedirs(plots_dir, exist_ok=True)

        for var in variables:
            var_data = self.data[var]
            if pd.api.types.is_numeric_dtype(var_data):
                
                # Generar grafico de densidad mediante histograma
                plt.figure(figsize=(10,8))
                sns.kdeplot(var_data, shade=True, color="r", label=var)
                plt.title(f'Densidad de distribución de {var}')
                plt.savefig(f'{plots_dir}/{var}_density_plot.pdf')
                plt.close()


            else:
                
                #Generar histograma para las N categorias principales de variables categoricas, ordenando de mayor a menor
                if pd.api.types.is_categorical_dtype(var_data):
                    top_categories_data = var_data.value_counts().head(top_categories).sort_values(ascending=False)
                    plt.figure(figsize=(10,8))
                    top_categories_data.plot(kind='bar')
                    plt.title(f'Principales {top_categories} categorias de {var}')
                    plt.savefig(f'{plots_dir}/{var}_top_categories_histogram.pdf')
                    plt.close()
                    #Almacenamos el nombre de las variables categoricas en una lista
                    categorical_variables.append(var)
            
            #Ahora graficamos el coeficiente de Cramer para las variables categoricas
            if len(categorical_variables) > 1:
                #Generamos una matriz de correlacion entre las variables categoricas
                corr_matrix = pd.DataFrame(index=categorical_variables, columns=categorical_variables)
                for var_1 in categorical_variables:
                    for var_2 in categorical_variables:
                        corr_matrix.loc[var_1, var_2] = self.cramers_v(self.data[var_1], self.data[var_2])
                
                #Graficamos la matriz de correlacion
                plt.figure(figsize=(10,8))
                sns.heatmap(corr_matrix.astype(float), annot=True,cmap='coolwarm', fmt=".2f")
                plt.title('Coeficiente de Cramers V')
                plt.savefig(f'{plots_dir}/cramer_correlation_matrix.pdf')
                plt.close()
        #Generar matriz de correlacion con variables numericas o categoricas
        plt.figure(figsize=(12,8))

        correlation_matrix = self.data.corr(numeric_only=True)
        #Graficamos la matriz de correlacion mostrando los valores
        sns.heatmap(correlation_matrix,cmap='coolwarm', fmt=".2f",annot=True)
        plt.title('Matriz de correlación')
        plt.savefig(f'{plots_dir}/correlation_matrix.pdf')
        plt.tight_layout() 
        plt.close()



    def cramers_v(self, x, y):
        """
        Calcula el coeficiente de asociación Cramer's V entre dos variables categóricas.

        Parámetros:
        x (pandas.Series): La primera variable categórica.
        y (pandas.Series): La segunda variable categórica.

        Retorna:
        float: El coeficiente de Cramer's V.
        """
        confusion_matrix = pd.crosstab(x,y)
        chi2 = chi2_contingency(confusion_matrix)[0]
        n = confusion_matrix.sum().sum()
        phi2 = chi2/n
        r,k = confusion_matrix.shape
        phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
        rcorr = r-((r-1)**2)/(n-1)
        kcorr = k-((k-1)**2)/(n-1)
        return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))


    def clean_data(self, data, variables=None, drop_duplicates=True, drop_na=True,n_cat = 60, reemplazar = False,clean_data_cruda = False):
        """
        Limpia y preprocesa el conjunto de datos.

        Parámetros:
        data (pandas.DataFrame): El conjunto de datos a limpiar.
        variables (lista, opcional): La lista de variables a considerar en la limpieza.
        drop_duplicates (bool, opcional): Si se deben eliminar las filas duplicadas.
        drop_na (bool, opcional): Si se deben eliminar los valores nulos.
        n_cat (int, opcional): Número máximo de categorías únicas para transformar en categóricas.
        reemplazar (bool, opcional): Si se debe reemplazar el conjunto de datos original.
        clean_data_cruda (bool, opcional): Si se debe limpiar el conjunto de datos crudos original.

        Retorna:
        pd.Dataframe: Conjunto de datos limpio.
        """

        clean_data_dir = os.path.join(self.output_dir, "clean_data")
        os.makedirs(clean_data_dir, exist_ok=True)
        clean_data_file = os.path.join(clean_data_dir, "data.csv")

        if variables is None:
            variables = data.columns

        if reemplazar == False:
            cleaned_data = data[variables].copy()
        else:
            cleaned_data = data

        # fijamos como indice la columna que tenga mayor numero de valores unicos
        cleaned_data.set_index(cleaned_data.columns[cleaned_data.nunique().argmax()], inplace=True)

        #Transformamos la columna Medal
        process_medal_transformer = FunctionTransformer(self.process_medal, validate=False)
        cleaned_data = process_medal_transformer.transform(cleaned_data)

        #Separamos las columnas no atomicas
        separate_non_atomic_transformer = FunctionTransformer(self.separate_non_atomic, validate=False)
        cleaned_data = separate_non_atomic_transformer.transform(cleaned_data)

        #Guardamos los valores de drop_na
        self.drop_na = drop_na  # Almacena el valor en una variable de clase

        if drop_duplicates:
            remove_duplicates_transformer = FunctionTransformer(self.remove_duplicates, validate=False)
            cleaned_data = remove_duplicates_transformer.transform(cleaned_data)

        #Tratamos los nulos
        handle_missing_values_transformer = FunctionTransformer(self.handle_missing_values, validate=False)
        cleaned_data = handle_missing_values_transformer.transform(cleaned_data)

        #Transformamos categoricas
        self.n_cat = n_cat
        to_categorical_transformer = FunctionTransformer(self.to_categorical, validate=False)
        cleaned_data = to_categorical_transformer.transform(cleaned_data)

        cleaned_data.to_csv(clean_data_file, index=False)
        self.cleaned = True
        data = cleaned_data
        self.data = cleaned_data
        if clean_data_cruda:
            self.cleaned = False

        return cleaned_data

    #Funciones Auxiliares para el clean_data
    #-Remover duplicados
    def remove_duplicates(self, data):
        """
        Elimina filas duplicadas del conjunto de datos.

        Parámetros:
        data (pandas.DataFrame): El conjunto de datos a procesar.

        Retorna:
        pandas.DataFrame: El conjunto de datos sin filas duplicadas.
        """
        data.drop_duplicates(inplace=True)
        return data

    #-Tratamiento de valores faltantes
    def handle_missing_values(self, data):
        """
        Gestiona los valores faltantes en el conjunto de datos.

        Parámetros:
        data (pandas.DataFrame): El conjunto de datos a procesar.

        Retorna:
        pandas.DataFrame: El conjunto de datos con valores faltantes gestionados.
        """
        if self.drop_na: #Eliminamos los valores nulos
            data.dropna(inplace=True)
        else: #Impuntamos los valores nulos
            for column in data.columns:
                if pd.api.types.is_numeric_dtype(data[column]):
                    imputer = SimpleImputer(strategy='mean')
                else:
                    imputer = SimpleImputer(strategy='most_frequent')
                data[column] = imputer.fit_transform(data[column].values.reshape(-1, 1)).flatten()
        return data

    def separate_non_atomic(self, data, separator=[':', '(', '?', '*']):
        """
        Separa las columnas no atómicas del conjunto de datos.

        Parámetros:
        data (pandas.DataFrame): El conjunto de datos a procesar.
        separator (lista, opcional): Lista de separadores para identificar columnas no atómicas.

        Retorna:
        pandas.DataFrame: El conjunto de datos con columnas no atómicas separadas.
        """
        separator_2 = [re.escape(char) for char in separator]
        no_atomicas = []

        for var in data.columns:
            if not pd.api.types.is_numeric_dtype(data[var]) and pd.api.types.is_string_dtype(data[var]):  # Verifica si es una columna de cadena
                for sep in separator_2:
                    if data[var].str.contains(sep).any() and not data[var].str.contains("\)").any():
                        no_atomicas.append(var)
                        break

        for var in no_atomicas:
            for sep in separator:
                data[var] = data[var].str.replace(sep, '-')

            n = data[var].str.count('-').max()

            for i in range(n + 1):
                data[var + '_' + str(i)] = data[var].str.split('-').str[i]
                # Las transformamos en numéricas
                data[var + '_' + str(i)] = pd.to_numeric(data[var + '_' + str(i)], errors='coerce')

            data.drop(var, axis=1, inplace=True)

        data.replace('nan', np.nan, inplace=True)

        return data

    
    #-Transformacion de categoricas
    def to_categorical(self, data, variables=None):
        """
        Convierte variables con un número limitado de valores únicos a categóricas.

        Parámetros:
        data (pandas.DataFrame): El conjunto de datos a procesar.
        variables (lista, opcional): Lista de variables a convertir a categóricas.

        Retorna:
        pandas.DataFrame: El conjunto de datos con variables convertidas a categóricas.
        """
        if variables is None:
            variables = data.columns

        for var in variables:
            #Vemos si la cantidad de valores unicos es menor a 100
            if data[var].nunique() < self.n_cat:
                #Si es menor a 100, la transformamos en categorica
                data[var] = data[var].astype('category')
        return data
    
    #-Procesamiento de columna de medallas
    def process_medal(self, data):
        """
        Procesa la columna de medallas en el conjunto de datos.

        Parámetros:
        data (pandas.DataFrame): El conjunto de datos a procesar.

        Retorna:
        pandas.DataFrame: El conjunto de datos con la columna de medallas procesada.
        """
        #Vemos la columna que tenga sobre el 75% de valores nulos
        columna = data.columns[data.isnull().mean() > 0.75]
        #Transformamos los nulos de la columna a "No Medal"
        data[columna] = data[columna].fillna("No Medal")
        return data
    
    def scale(self, data, numeric_scaler=None, categorical_encoder=None):
        """
        Escala y transforma las variables numéricas y categóricas.

        Parámetros:
        data (pandas.DataFrame): El conjunto de datos a escalar.
        numeric_scaler (lista, opcional): El escalador para variables numéricas.
        categorical_encoder (objeto, opcional): El codificador para variables categóricas.

        Retorna:
        pd.Dataframe: Conjunto de datos escalado.
        """
        scale_dir = os.path.join(self.output_dir, "scale")
        os.makedirs(scale_dir, exist_ok=True)

        numeric_features = data.select_dtypes(include=[np.number])
        categorical_features = data.select_dtypes(include=['category'])

        if numeric_scaler is None:
            numeric_scaler = [FunctionTransformer(np.log1p), MinMaxScaler()]

        numbers = numeric_features.columns.copy()
        #Variables numericas
        for col in numeric_features.columns:
            for scaler in numeric_scaler:
                transformer = ColumnTransformer(transformers=[('num', scaler, [col])])
                numeric_transformer = transformer.fit_transform(data[[col]])
                data[col] = numeric_transformer[:, 0]

        #Variables Categoricas 
        if categorical_encoder is None:
            categorical_encoder = OneHotEncoder()


        if categorical_encoder is not None:
            if isinstance(categorical_encoder, LabelEncoder):
                #LabelEncoder
                for col in categorical_features.columns:
                    encoder = LabelEncoder()
                    data[col] = encoder.fit_transform(data[col])
            elif isinstance(categorical_encoder, OneHotEncoder):
                #OneHotEncoder
                categorical_encoder.sparse_output = False
                cols_cat = categorical_features.columns.to_list()
                ct = ColumnTransformer(transformers=[('cat', categorical_encoder, cols_cat)], remainder='passthrough')
                x = ct.fit_transform(data)

                #Nuevo Df
                df = pd.DataFrame(x)
                nombres = ct.named_transformers_['cat'].get_feature_names_out(cols_cat)
                df.columns = nombres.tolist() + data.columns[~data.columns.isin(cols_cat)].tolist()
                order = data.columns[~data.columns.isin(cols_cat)].tolist() + nombres.tolist()
                df = df.reindex(columns=order)
                data = df
                #Dejamos las variables codificadas como numericas
                for col in nombres:
                    data[col] = data[col].astype('int64') 

                #Dejamos las variables numericas como numericas+
                for col in numbers:
                    data[col] = data[col].astype('float64')

        # le damos el formato de origen a las variables categoricas

        data.to_csv(os.path.join(scale_dir, "scaled_data.csv"), index=False)
        self.scaled = True
        self.data = data
        return data



    def make_clusters(self, clustering_algorithm, max_clusters=10, pca_components=2):
        """
        Realiza el análisis de clústeres sobre el conjunto de datos.

        Parámetros:
        clustering_algorithm (objeto): Algoritmo de clustering a utilizar.
        max_clusters (int, opcional): El número máximo de clústeres a considerar.
        pca_components (int, opcional): Número de componentes PCA para la visualización.

        Retorna:
        pd.Dataframe: Conjunto de datos con etiquetas de clúster.
        """
        clusters_dir = os.path.join(self.output_dir, "clusters")
        os.makedirs(clusters_dir, exist_ok=True)
        clusters_file = os.path.join(clusters_dir, "data_clusters.csv")

        data_for_clustering = self.data.copy()
        data_cruda = self.data_cruda.copy()
        data_cruda_limpia = self.clean_data(data_cruda, clean_data_cruda=True)

        #Creamos un pipeline que procese los datos con los metodos clean_data() y scale() en caso que no esten limpios y escalados

        steps_pipeline = []

        if not self.cleaned:
            steps_pipeline.append(('clean_data', FunctionTransformer(self.clean_data, validate=False)))

        if not self.scaled:
            steps_pipeline.append(('scale', FunctionTransformer(self.scale, validate=False)))


        if not self.cleaned or not self.scaled:
            pipeline = Pipeline(steps=steps_pipeline)
            data_for_clustering = pipeline.fit_transform(data_for_clustering)

        #Filtrar columnas de interes
        data_cluster_filtrada = data_for_clustering.select_dtypes(include=[np.number]).copy()

        #Visualizer para metodo del codo
        model = clustering_algorithm(random_state=10)
        visualizer = KElbowVisualizer(model, k=(2, max_clusters+1))


        visualizer.fit(data_cluster_filtrada.sample(frac=0.1, random_state=42))
        visualizer.show()
        #Obtener el numero optimo de clusters
        optimal_clusters = visualizer.elbow_value_
        print(f'Clusters seleccionados: {optimal_clusters}')

        # Ajusta el modelo de clustering con el número óptimo de clusters
        model_2 = clustering_algorithm(n_clusters=optimal_clusters,random_state=42)
        clusters = model_2.fit_predict(data_cluster_filtrada)
        data_for_clustering['cluster'] = clusters
        data_cruda_limpia['cluster'] = clusters

        # Reducción de dimensionalidad (PCA) para la visualización en 2D
        pca = PCA(n_components=pca_components)
        data_pca = pca.fit_transform(data_cluster_filtrada)

        # Grafica los datos en 2D y colorea por cluster con Plotly
        plt.figure(figsize=(10,8))
        fig = plt.scatter(x=data_pca[:, 0], y=data_pca[:, 1], c=data_for_clustering['cluster'],
                        alpha=1,cmap='rainbow',s=3)
        plt.title('Proyección PCA con Etiquetas de Cluster')
        plt.xlabel('PC1')
        plt.ylabel('PC2')
        plt.show()

        # Guarda el número óptimo de clusters en un archivo
        optimal_clusters_file = os.path.join(clusters_dir, "optimal_clusters.txt")
        with open(optimal_clusters_file, "w") as f:
            f.write(f"Número óptimo de clusters: {optimal_clusters}\n")

        # Guarda los datos con etiquetas de cluster
        data_for_clustering.to_csv(clusters_file, index=False)

        return data_cruda_limpia

    def detect_anomalies(self, anomaly_detector, pca_components=2):
        """
        Detecta anomalías en el conjunto de datos.

        Parámetros:
        anomaly_detector (objeto): Detector de anomalías a utilizar.
        pca_components (int, opcional): Número de componentes PCA para la visualización.

        Retorna:
        pd.Dataframe: Conjunto de datos con etiquetas de anomalía.
        """
        # se aplica sobre todas las variables menos las de tipo 'object'

        # Crear la carpeta 'anomalies' en la carpeta de salida
        anomalies_dir = os.path.join(self.output_dir, "anomalies")
        os.makedirs(anomalies_dir, exist_ok=True)

        raw_data = self.data.copy()

        if 'cluster' in raw_data.columns:
            raw_data = raw_data.drop(columns=['cluster'])
        
        steps_pipeline = []

        if not self.cleaned:
            steps_pipeline.append(('clean_data', FunctionTransformer(self.clean_data, validate=False)))

        if not self.scaled:
            steps_pipeline.append(('scale', FunctionTransformer(self.scale, validate=False)))
        

        if not self.cleaned or not self.scaled:
            pipeline = Pipeline(steps=steps_pipeline)
            raw_data = pipeline.fit_transform(self.data)

        # Filtrar las columnas que son numéricas o categóricas (transformadas en int)
        valid_columns = raw_data.select_dtypes(include=[np.number]).columns

        if not valid_columns.empty:
            numeric_data = raw_data[valid_columns]

            # Verificar si hay al menos una columna numérica o categórica para realizar la detección de anomalías
            if numeric_data.shape[1] > 0:
                # Aplicar el detector de anomalías (anomaly_detector) a las variables numéricas o categóricas
                anomaly_labels = anomaly_detector.fit_predict(numeric_data)

                # Proyectar los datos a 2 dimensiones usando PCA
                pca = PCA(n_components=pca_components)
                data_pca = pca.fit_transform(numeric_data)

                # Graficar los datos en 2D y colorear por las etiquetas de anomalía con Plotly
                plt.figure(figsize=(10,8))
                fig = plt.scatter(x=data_pca[:, 0], y=data_pca[:, 1], c=anomaly_labels,
                               cmap='rainbow',s=4)
                plt.title('Proyección PCA con Etiquetas de Anomalía')
                plt.xlabel('PC1')
                plt.ylabel('PC2')
                plt.show()

                # Guardar los datos con etiquetas de anomalía en un archivo CSV
                numeric_data['anomaly'] = anomaly_labels
                raw_data['anomaly'] = anomaly_labels
                anomalies_file = os.path.join(anomalies_dir, "data_anomalies.csv")
                numeric_data.to_csv(anomalies_file, index=False)
            else:
                print("No hay variables numéricas o categóricas para la detección de anomalías.")
        else:
            print("No hay variables numéricas o categóricas para la detección de anomalías.")

        return raw_data


    def profile(self,clustering_algorithm, anomaly_detector, numeric_scaler = None, categorical_encoder = None,view=False):
        """
        Realiza un perfilado completo del conjunto de datos.

        Parámetros:
        clustering_algorithm (objeto): Algoritmo de clustering a utilizar.
        anomaly_detector (objeto): Detector de anomalías a utilizar.
        numeric_scaler (lista, opcional): El escalador para variables numéricas.
        categorical_encoder (objeto, opcional): El codificador para variables categóricas.
        view (bool, opcional): Si se debe mostrar la información generada.
        """
        # Paso 8: Método para realizar el perfilado
        
        if not self.cleaned:
            self.clean_data(self.data)
    
        self.summarize(view=view)
        self.plot_vars()
        if not self.scaled:
            self.scale(self.data,numeric_scaler, categorical_encoder)

        # Realiza el clustering y guarda los resultados
        self.make_clusters(clustering_algorithm)
        
        # Realiza la detección de anomalías y guarda los resultados
        self.detect_anomalies(anomaly_detector)


    def clearGarbage(self):
        """
        Elimina los directorios/archivos creados por la clase Profiler.
        """
        # Paso 9: Método para eliminar las carpetas/archivos creados por la clase
        shutil.rmtree(self.output_dir)

# %% [markdown]
# ## 1.2 Caracterizar datos de Olimpiadas (2.0 puntos)
#
# A partir de la clase que hemos desarrollado previamente, procederemos a realizar un análisis exhaustivo de los datos proporcionados en el enunciado. Este análisis se presentará en forma de un informe contenido en el mismo Jupyter Notebook y abordará los siguientes puntos:
#
# 1. Introducción
#     - Se proporcionará una breve descripción del problema que estamos abordando y se explicará la metodología que se seguirá.
#
# Elaborar una breve introducción con todo lo necesario para entender qué realizarán durante su proyecto. La idea es que describan de manera formal el proyecto con sus propias palabras y logren describir algunos aspectos básicos tanto del dataset como del análisis a realizar sobre los datos.
#
# Por lo anterior, en esta sección ustedes deberán ser capaces de:
#
# - Describir la tarea asociada al dataset.
# - Describir brevemente los datos de entrada que les provee el problema.
# - Plantear hipótesis de cómo podrían abordar el problema.
#
#
#
# 2. Análisis del EDA (Análisis Exploratorio de Datos)
#     - Se discutirán las observaciones y conclusiones obtenidas acerca de los datos proporcionados. A lo largo de su respuesta, debe responder preguntas como:
#         - ¿Como se comportan las variables numéricas? ¿y las categóricas?
#         - ¿Existen valores nulos en el dataset? ¿En qué columnas? ¿Cuantos?
#         - ¿Cuáles son las categorías y frecuencias de las variables categóricas?
#         - ¿Existen datos duplicados en el conjunto?
#         - ¿Existen relaciones o patrones visuales entre las variables?
#         - ¿Existen anomalías notables o preocupantes en los datos?
# 3. Creación de Clusters y Anomalías
#     - Se justificará la elección de los algoritmos a utilizar y sus hiperparámetros. En el caso de clustering, justifique además el número de clusters.
#
# 4. Análisis de Resultados
#     - Se examinarán los resultados obtenidos a partir de los clústers y anomalías generadas. ¿Se logra una separación efectiva de los datos? Entregue una interpretación de lo que representa cada clúster y anomalía.
# 5. Conclusión
#     - Se resumirán las principales conclusiones del análisis y se destacarán las implicaciones prácticas de los resultados obtenidos.

# %% [markdown]
# ### **INTRODUCCIÓN**
#
# En un hito histórico para Chile, el país acaba de concluir su primer evento panamericano, los Juegos de Santiago 2023. Este acontecimiento deportivo ha envuelto a la sociedad chilena en su totalidad, generando una ola de entusiasmo y emoción sin precedentes. En un momento en que la nación enfrenta desafíos políticos y económicos críticos, los Juegos de Santiago 2023 se presentan como una oportunidad crucial. Más allá de destacar a nivel internacional, estos juegos ofrecen un respiro bienvenido a una sociedad ávida de celebración y unión.
#
# El presidente de la República ha convocado a un equipo de expertos en análisis de datos y estadísticas para liderar un proyecto, donde la premisa subyacente radica en la creencia de que un análisis detallado de los datos generados por los juegos no solo proporcionará información valiosa, sino que permitirá tomar decisiones informadas y anticiparse a los desafíos que puedan surgir en el camino hacia la revitalización de Chile.
#
# En este contexto, el análisis de datos se convierte en una herramienta fundamental. La tarea asociada a este análisis es comprender y obtener información relevante a partir de los datos de las Olimpiadas, lo que implica la identificación de patrones, tendencias y características destacadas en estos datos. La finalidad de este análisis es proporcionar información valiosa y significativa sobre el evento olímpico, sus participantes y los resultados obtenidos a lo largo de los años.
#
# Los datos de entrada para este análisis se componen de una amplia variedad de atributos que describen los eventos olímpicos, los atletas, las disciplinas deportivas y los resultados obtenidos. Algunos de los posibles atributos incluyen el año de la Olimpiada, la ciudad anfitriona, el deporte, eventos específicos, información sobre los participantes (nombre, país, edad, altura, peso) y las medallas ganadas. Estos datos son esenciales para llevar a cabo un análisis en profundidad y revelar información interesante y útil.
#
# En este proyecto, se creará una clase Profiler versátil para analizar los datos. Se tiene la hipotesis de que esta herramienta permitirá realizar una caracterización de las variables, generar visualizaciones significativas, llevar a cabo la limpieza de datos necesaria y detectar posibles anomalías. Se llevará a cabo un análisis exhaustivo de los datos de las Olimpiadas, abordando aspectos críticos como la gestión de valores nulos, la identificación de datos duplicados y la búsqueda de patrones visuales que arrojen luz sobre los eventos deportivos.
#
# A medida que avanzamos en este proyecto, abordaremos estas tareas con un propósito definido. Partiremos de hipótesis iniciales que nos guiarán en el análisis, y ajustaremos o desarrollaremos nuevas hipótesis según las observaciones realizadas en el Análisis Exploratorio de Datos (EDA). Es fundamental recordar que estas hipótesis iniciales son suposiciones que serán validadas o descartadas por los resultados del análisis de datos.
#
# El objetivo final de este proyecto es sentar las bases necesarias para tomar decisiones informadas y contribuir al éxito de un evento crucial que impulsa la revitalización de Chile y celebra el espíritu olímpico en el corazón de esta nación apasionada por el deporte.

# %% [markdown]
# ### **ANALISIS EXPLORATORIO DE LOS DATOS**
#
# **Data Original**

# %% [markdown]
# Para esta sección, se utilizará la función summarize() de la clase creada, seleccionando la opción view = True en los datos iniciales, es decir, sin un procesamiento previo. Esto nos permite dimensionar las posibles anomalías en los datos para determinar la forma de realizar un futuro preprocesamiento.

# %%
datos = data.copy()
clase = Profiler(datos)
clase.summarize(view=True)
# Out:
# Variable: ID
# Tipo Variable: int64
# Valores Unicos: 135571
# Porcentaje de Valores Faltantes: 0.00%
# Numero de Ceros: 0
# Número de Valores Negativos: 0
# Número de Outliers: 0
# Min: 1
# Max: 135571
# Promedio: 68248.95439590434
# Percentiles: 0.25     34643.00
# 0.50     68205.00
# 0.75    102097.25
# 1.00    135571.00
# Name: ID, dtype: float64
#
# Variable: Name
# Tipo Variable: object
# Valores Unicos: 134732
# Porcentaje de Valores Faltantes: 0.00%
# Anomalia Detectada! Alto Numero de Valores Unicos
# Tipo de Anomalia: Alta Cardinalidad (Valores Unicos: 134732)
#
# Variable: Sex
# Tipo Variable: object
# Valores Unicos: 2
# Porcentaje de Valores Faltantes: 0.00%
#
# Variable: Team
# Tipo Variable: object
# Valores Unicos: 1184
# Porcentaje de Valores Faltantes: 0.00%
# Anomalia Detectada! Alto Numero de Valores Unicos
# Tipo de Anomalia: Alta Cardinalidad (Valores Unicos: 1184)
#
# Variable: NOC
# Tipo Variable: object
# Valores Unicos: 230
# ...

# %% [markdown]
# El conjunto de datos original se compone de diversas variables que ofrecen información detallada sobre los eventos olímpicos. Algunas variables destacadas incluyen "ID," una variable numérica que funciona como un identificador único para cada entrada en el conjunto de datos. Esta variable se caracteriza por no contener valores negativos, nulos ni atípicos, abarcando un rango desde 1 hasta 135,571, con un valor promedio de alrededor de 68,249.
#
# La variable "Name" se clasifica como tipo objeto y contiene los nombres de los participantes en los eventos olímpicos. Destaca por una alta cardinalidad, con 134,732 valores únicos, lo que refleja una amplia diversidad de nombres en el conjunto de datos. No se encontraron valores nulos en esta variable.
#
# Por otro lado, "Sex" es una variable categórica con dos valores únicos que representan el género de los participantes (masculino y femenino), sin valores nulos.
#
# La variable "Team" mantiene su tipo como objeto, presenta 1,184 valores únicos y no se registran valores faltantes, lo que también constituye una anomalía de alta cardinalidad.
#
# La variable "NOC" es otra variable de tipo objeto con 230 valores únicos y sin valores faltantes, también mostrando una anomalía de alta cardinalidad.

# %% [markdown]
# **Data procesada**
#
# En este caso, se realiza un procesamiento de los datos a través de la funcion de la clase clean_data. Se utilizará un umbral de valores únicos de 60 (por defecto) para determinar si la columna corresponde a una categoría o a otro tipo de variable (se mantendrá como objeto). Esto se debe a que como se vió en el análisis de los datos crudos, existen variables que por naturaleza podrían ser interpretadas como categóricas (ex. variable Team), al tener tantas categorías se podría entregar información que no es útil para un análisis o trabajo posterior, logrando incluso dificultar alguna labor posterior. Adicionalmente se utiliza la opción de eliminar los nulos en lugar de realizar una inputación de estos, debido a que se podría introducir un sesgo en los datos determinados por la media en las variables numéricas o la moda en las categóricas. De esta forma, utilizando la función clean_data de la clase creada, se obtienen los nuevos datos ya procesados:

# %%
data_limpia = clase.clean_data(datos,drop_na=True)
clase.plot_vars()
clase.summarize(view=True)
# Out:
# C:\Users\andmo\AppData\Local\Temp\ipykernel_17708\3720106485.py:73: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(var_data, shade=True, color="r", label=var)
# C:\Users\andmo\AppData\Local\Temp\ipykernel_17708\3720106485.py:73: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(var_data, shade=True, color="r", label=var)
# C:\Users\andmo\AppData\Local\Temp\ipykernel_17708\3720106485.py:73: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(var_data, shade=True, color="r", label=var)
# Variable: Name
# Tipo Variable: object
# Valores Unicos: 98546
# Porcentaje de Valores Faltantes: 0.00%
# ...

# %% [markdown]
# Luego de un minucioso proceso de limpieza de datos, se obtienen los siguientes resultados:
#
# La variable "Name" conserva su tipo de objeto y muestra 98,546 valores únicos sin valores faltantes, manteniendo una anomalía de alta cardinalidad. La variable "Sex" se ha transformado con éxito en una variable categórica, con 2 valores únicos y sin valores faltantes.
#
# La variable "Team" continúa siendo de tipo objeto, con 660 valores únicos y sin valores faltantes, manteniendo la alta cardinalidad. De manera similar, la variable "NOC" permanece como objeto, con 226 valores únicos y sin valores faltantes, lo que también constituye una anomalía de alta cardinalidad.
#
# Respecto a las variables "Games," "Year," "Season," y "City," se han convertido en variables categóricas, todas con un número limitado de valores únicos y sin valores faltantes. Por ejemplo, "Games" posee 51 valores únicos, "Year" presenta 35 valores únicos, "Season" cuenta con 2 valores únicos, y "City" exhibe 42 valores únicos, sin valores faltantes.
#
# De igual manera, la variable "Sport" ha sido transformada en una variable categórica, con 56 valores únicos y sin valores faltantes. La variable "Event" continúa siendo de tipo objeto, pero ahora muestra 590 valores únicos, sin valores faltantes, lo que representa una alta cardinalidad. La variable "Medal" se ha convertido en una variable categórica, con 4 valores únicos y sin valores faltantes.
#
# Respecto a las variables numéricas, es importante mencionar que tras el proceso de limpieza, las variables "age-height-weight_0," "age-height-weight_1," y "age-height-weight_2" muestran comportamientos más uniformes. Las tres variables son de tipo float64 y no presentan valores faltantes, ceros ni valores negativos. Sin embargo, se han identificado valores atípicos en todas ellas, con rango y promedios específicos:
#
# - "age-height-weight_0" muestra 2,614 valores atípicos, con un rango desde 11.0 hasta 71.0 y un promedio de 25.05.
# - "age-height-weight_1" presenta 855 valores atípicos, con un rango desde 127.0 hasta 226.0 y un promedio de 175.37.
# - "age-height-weight_2" exhibe 2,113 valores atípicos, con un rango desde 25.0 hasta 214.0 y un promedio de 70.69.
#
# Este análisis confirma que la limpieza de datos ha sido efectiva en la eliminación de valores nulos, ceros y valores negativos en las variables numéricas. Las variables categóricas han sido transformadas con éxito, aunque persisten anomalías de alta cardinalidad en algunas de ellas. Además, se han identificado valores atípicos en las variables numéricas que podrían requerir una revisión adicional para determinar su relevancia en el análisis global de los datos.
#
# Dentro de la correlacion entre variables numericas vemos que se comporta bien la relacion entre peso y altura respectivamente ya que ambas se encuentra relacionas lo que se evidencia con la teoria y los datos.
#
# <div style="text-align:center">
#   <img src="img_example/matriz_correlacion.png" width="600" height="500">
# </div>
#
# Por otro lado entre las variables categoricas vemos que Games tiene correlacion positiva con Year, Season y City. Esto hace sentido, ya que Games tiene valores compuestos por otras variables como Year y Season. Sport y Season tambien se correlacionan, esto ya que hay deportes que solo se practican en invierno como lo es el ski y deportes de verano por otro lado.
#
# <div style="text-align:center">
#   <img src="img_example/matriz_cramer.png" width="600" height="500">
# </div>
#
# En cuanto a la distribución de las variables numéricas, se obtiene el siguiente gráfico de la variable age-height-weight_0 (age):
#
# <div style="text-align:center">
#   <img src="img_example/age.png" width="600" height="500">
# </div>

# %% [markdown]
# Donde se puede apreciar una gran cantidad de personas con una edad cerca de la media de 25 años, obteniendo una cola derecha de baja densidad, es decir, muy pocas personas con edades superiores a los 40 años, y por el otro lado, una cola prácticamente inexistente para edades inferiores a los 12 años.
#
# Respecto a la variable age-height-weight_1 (altura), se tiene la siguiente distribución:
#
# <div style="text-align:center">
#   <img src="img_example/height.png" width="600" height="500">
# </div>

# %% [markdown]
# En este caso se puede apreciar que existen tres grandes peak en valores cercano a 1.70, 1.75 y 1.80 metros. Esto indica que existe una gran cantidad de personas que tiene una altura muy similar muy cercana a este rango de valores, pero que para para valores que comienzan a alejarse de este rango, la cantidad de personas con esta estatura disminuye considerablemente, marcando una pseudocampana que decae de forma muy pronunciada, con colas de muy baja densidad.
#
# Respecto a la variable age-height-weight_2 (peso), se tiene la siguiente distribución:
#
# <div style="text-align:center">
#   <img src="img_example/weight.png" width="600" height="500">
# </div>

# %% [markdown]
# Se puede apreciar que tienen un comportamiento similar a la variable anterior (estatura), donde se presentan peaks en un intervalo de valores cercanos entre los 68 y 75 kg, para luego disminuir considerablemente a medida que se aleja de este valor medio. Esto indica que son muchas las personas que poseen un peso muy similar cercano a los 70 kg en la base de datos, y que son muy pocas las que tienen valores alejados a este valor. Similar al comportamiento con la altura, a medida que se desplaza el valor hacia las colas, la cantidad de personas disminuye considerablemente, aunque en este caso la cola derecha (pesos de mayor magnitud) presenta un decaimiento mas lento que la cola izquierda (menores pesos).
#
# Esto hace sentido con la correlación vista en el análisis anterior, donde peso y altura estaban fuertemente correlacionadas, pues personas de cierta altura y entendiendo el contexto del set de datos, tenderían a tener un peso similar.

# %% [markdown]
# **Escalamiento de Datos**
#
# Con los datos ya procesados, se realiza un escalamiento de datos a través de 2 métodos:
# - Escalamiento datos numéricos
# - Codificación de datos categóricos
#
# Para los datos numéricos, se decide utilizar la opción por defecto que consiste en aplicar 2 métodos de forma secuencial: Primero un escalador logarítmico y luego un `MinMaxScaler`.
# Para los datos categóricos, se decide utilizar OneHotEncoder, ya que este permite transformar este tipo de variables en dummies que facilitan el tratamiento y posterior trabajo de los datos, como algún algoritmo de machine learning, clustering, detección de anomalías, etc.
#
# Para el caso de las variables numéricas, se procede a observar el cambio de los datos ya limpios antes y despues de realizar el escalado.

# %%
data_limpia.describe()
# Out:
#        age-height-weight_0  age-height-weight_1  age-height-weight_2
# count        206152.000000        206152.000000        206152.000000
# mean             25.054736           175.372056            70.688332
# std               5.481679            10.545816            14.340633
# min              11.000000           127.000000            25.000000
# 25%              21.000000           168.000000            60.000000
# 50%              24.000000           175.000000            70.000000
# 75%              28.000000           183.000000            79.000000
# max              71.000000           226.000000           214.000000

# %%
clase.scale(data_limpia).describe()
# Out:
#        age-height-weight_0  age-height-weight_1  age-height-weight_2
# count        206152.000000        206152.000000        206152.000000  \
# mean              0.421180             0.556394             0.470908
# std               0.112259             0.104813             0.093225
# min               0.000000             0.000000             0.000000
# 25%               0.338291             0.485004             0.403674
# 50%               0.409636             0.555844             0.475533
# 75%               0.492471             0.633432             0.532027
# max               1.000000             1.000000             1.000000
#
#                Sex_F          Sex_M  Games_1896 Summer  Games_1900 Summer
# count  206152.000000  206152.000000      206152.000000      206152.000000  \
# mean        0.323601       0.676399           0.000194           0.000344
# std         0.467851       0.467851           0.013928           0.018555
# ...

# %% [markdown]
# En este caso se puede apreciar que los datos numéricos fueron ajustados a valores entre 0 y 1, donde previamente se aplicó una transformación logarítmica. Adicionalmente se puede apreciar que se realizó la transformación de variables binarias de los datos categóricos, donde todas las variables toman valores binarios (0 y 1)

# %% [markdown]
# ### **Clusters y Anomalías**
#
# Con los datos ya limpios y con los escalamientos aplicados, se aplica un método de clusters a través de K-Modes, esto debido a que se tiene una baja cantidad de variables numéricas y alta cantidad de variables categóricas. K-Modes tiene un mayor poder de clusterización en comparación con otros algoritmos que funcionan de forma efectiva solamente con variables numéricas, como lo son K-Means por ejemplo.
#
# Para determinar el número de clusters a utilizar, se empleó el método del codo de forma óptima, considerando un rango de 2 a 10 clusters, esto debido a que 2 es el valor mínimo de información que aportaría en los datos, y 10 debido a que se posee una gran cantidad de datos, por ende se debe ser consciente del costo computacional que esto puede implicar al momento de hacer el análisis de codo. Para ello se utiliza KElbowVisualizer, un algoritmo que se basa en el principio del método del codo, donde evalúa la varianza dentro de los clusters con diferentes cantidades de clusters. La idea es encontrar el punto donde la adición de más clusters ya no reduce significativamente la varianza dentro de cada cluster.
#
# Luego de esto, se reduce la dimensionalidad de los datos a solo 2 dimensiones a través del Análisis de Componentes Principales (PCA) y se realizó la clusterización de los datos en base al número óptimo obtenido anteriormente. A continuación se presentan los resultados:

# %%
datos = data.copy()
clase = Profiler(datos)
data_clusters = clase.make_clusters(KModes)
# Out:
# Clusters seleccionados: 4
# C:\Users\andmo\AppData\Local\Temp\ipykernel_17708\3720106485.py:350: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_for_clustering['cluster'] = clusters

# %%
data_clusters['cluster'].value_counts()
# Out:
# cluster
# 0    113659
# 2     53034
# 3     25976
# 1     13483
# Name: count, dtype: int64

# %% [markdown]
# A continuación se observa una descripción de los datos para cada cluster.

# %%
#Cluster 0
data_clusters.query('cluster == 0').describe()
# Out:
#        age-height-weight_0  age-height-weight_1  age-height-weight_2   cluster
# count        113659.000000        113659.000000        113659.000000  113659.0
# mean             25.692229           179.020781            75.647432       0.0
# std               5.501772             9.886708            13.737672       0.0
# min              12.000000           127.000000            28.000000       0.0
# 25%              22.000000           172.000000            66.000000       0.0
# 50%              25.000000           179.000000            74.000000       0.0
# 75%              28.000000           185.000000            83.000000       0.0
# max              71.000000           226.000000           214.000000       0.0

# %%
#Cluster 1
data_clusters.query('cluster == 1').describe()
# Out:
#        age-height-weight_0  age-height-weight_1  age-height-weight_2  cluster
# count         13483.000000         13483.000000         13483.000000  13483.0
# mean             24.275161           166.608544            59.808908      1.0
# std               4.626930             6.007980             7.074090      0.0
# min              11.000000           137.000000            32.000000      1.0
# 25%              21.000000           163.000000            55.000000      1.0
# 50%              24.000000           167.000000            60.000000      1.0
# 75%              27.000000           170.000000            64.000000      1.0
# max              48.000000           194.000000            96.000000      1.0

# %%
#Cluster 2
data_clusters.query('cluster == 2').describe()
# Out:
#        age-height-weight_0  age-height-weight_1  age-height-weight_2  cluster
# count         53034.000000         53034.000000         53034.000000  53034.0
# mean             23.653750           168.106422            60.010399      2.0
# std               5.754005             9.278893            10.838126      0.0
# min              11.000000           127.000000            25.000000      2.0
# 25%              19.000000           162.000000            53.000000      2.0
# 50%              23.000000           168.000000            59.000000      2.0
# 75%              27.000000           174.000000            66.000000      2.0
# max              69.000000           213.000000           167.000000      2.0

# %%
#Cluster 3
data_clusters.query('cluster == 3').describe()
# Out:
#        age-height-weight_0  age-height-weight_1  age-height-weight_2  cluster
# count         25976.000000         25976.000000         25976.000000  25976.0
# mean             25.530336           178.789575            76.437269      3.0
# std               4.582219             6.545494            10.280324      0.0
# min              12.000000           142.000000            47.000000      3.0
# 25%              22.000000           175.000000            69.000000      3.0
# 50%              25.000000           179.000000            75.000000      3.0
# 75%              28.000000           183.000000            83.000000      3.0
# max              55.000000           206.000000           145.000000      3.0

# %% [markdown]
# En el mismo sentido de valores anómalos, se aplicó un proceso de detección de anomalías en los datos ya limpios y escalados. Para ello se utiliza el algoritmo IsolationForest solamente debido a la sencillez de este método. Considerando el resultado obtenido del cluster, donde los datos anómalos en cuanto a clústers era una pequeña cantidad, se dedice ajustar el hiperparámetro contamination fijando el valor en 1%.
# Adicionalmente, al igual que con la aplicación de clusters, se realiza una reducción de dimensionalidad a 2 componentes principales a través de PCA.
#
# A continuación se presentan los resultados obtenidos:

# %%
datos = data.copy()
clase = Profiler(datos)
df_anomalias = clase.detect_anomalies(IsolationForest(contamination=0.01))
# Out:
# C:\Users\andmo\AppData\Local\Temp\ipykernel_17708\3720106485.py:426: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   numeric_data['anomaly'] = anomaly_labels
# C:\Users\andmo\AppData\Local\Temp\ipykernel_17708\3720106485.py:426: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_data['anomaly'] = anomaly_labels
# ...

# %%
df_anomalias['anomaly'].value_counts()
# Out:
# anomaly
#  1    204090
# -1      2062
# Name: count, dtype: int64

# %%
#Anomalias
df_anomalias.query('anomaly == -1').describe()
# Out:
#        age-height-weight_0  age-height-weight_1  age-height-weight_2
# count          2062.000000          2062.000000          2062.000000  \
# mean              0.416125             0.537015             0.462533
# std               0.119703             0.121264             0.101769
# min               0.086033             0.118604             0.051691
# 25%               0.338291             0.453742             0.395849
# 50%               0.409636             0.535895             0.462007
# 75%               0.492471             0.614356             0.534239
# max               0.829009             0.937376             0.803644
#
#              Sex_F        Sex_M  Games_1896 Summer  Games_1900 Summer
# count  2062.000000  2062.000000             2062.0             2062.0  \
# mean      0.523763     0.476237                0.0                0.0
# std       0.499556     0.499556                0.0                0.0
# ...

# %%
#Datos normales
df_anomalias.query('anomaly == 1').describe()
# Out:
#        age-height-weight_0  age-height-weight_1  age-height-weight_2
# count        204090.000000        204090.000000        204090.000000  \
# mean              0.421231             0.556589             0.470992
# std               0.112180             0.104615             0.093131
# min               0.000000             0.000000             0.000000
# 25%               0.338291             0.485004             0.403674
# 50%               0.409636             0.555844             0.475533
# 75%               0.492471             0.633432             0.532027
# max               1.000000             1.000000             1.000000
#
#                Sex_F          Sex_M  Games_1896 Summer  Games_1900 Summer
# count  204090.000000  204090.000000      204090.000000      204090.000000  \
# mean        0.321579       0.678421           0.000196           0.000348
# std         0.467083       0.467083           0.013998           0.018648
# ...

# %% [markdown]
# ### **Análisis de Resultados**

# %% [markdown]
# Respecto al proceso de creación de Clusters, inicialmente se puede apreciar que mediante el método del codo se determinó que el número óptimo de clusters corresponde a 4, el que luego fue aplicado al método K-Modes. En el gráfico se puede observar que se logran distinguir 4 conjuntos de datos en el análisis con la dimensión reducida a 2. Adicionalmente, se pueden observar que en cada conjunto distinguible de datos existe la presencia del cluster principal y un pequeño conjunto de datos perteneciente a otro cluster. También es posible identificar que gran parte de los datos se agrupa en el cluster 0, logrando reunir mas de la mitad de los registros.
#
# Con la descripción de los datos, enfocándose solamente en las variables numéricas debido a la gran cantidad de variables categóricas, se puede obtener para cada cluster un pequeño análisis:

# %% [markdown]
# En el Cluster 0, notamos que la población es más numerosa con 113,659 registros. Aquí, la edad promedio es alrededor de 25.7 años, con una estatura media de 179 cm y un peso promedio de 75.6 kg. En este cluster es posible apreciar que la dispersión en edad es relativamente baja, con una desviación estándar de aproximadamente 5.5 años, mientras que la variabilidad en estatura y peso es más amplia, indicada por desviaciones de 9.9 y 13.7 respectivamente. Este cluster abarca un rango de edad desde 12 hasta 71 años, con variaciones notables en estatura y peso, desde 127 cm hasta 226 cm y desde 28 kg hasta 214 kg respectivamente.
#
# En el Cluster 1, el grupo es considerablemente más reducido con 13,483 registros. Aquí, la edad promedio es alrededor de 24.3 años, con una estatura media de 166.6 cm y un peso promedio de 59.8 kg. La dispersión en edad es similar al Cluster 0, pero la variabilidad en estatura y peso es menos amplia, indicada por desviaciones estándar más bajas, lo que refleja una mayor homogeneidad en estos aspectos dentro de este cluster.
#
# El Cluster 2, con 53,034 registros, muestra una edad promedio ligeramente menor que los anteriores, alrededor de 23.7 años, con una estatura media de 168.1 cm y un peso promedio de 60 kg. Aquí, la dispersión en edad es la más alta entre los clusters, y la variabilidad en estatura y peso es moderada. Este cluster abarca un rango de edad desde 11 hasta 69 años, con variaciones de estatura desde 127 cm hasta 213 cm y de peso desde 25 kg hasta 167 kg.
#
# Por último, el Cluster 3 contiene 25,976 registros con una edad promedio similar al Cluster 0, alrededor de 25.5 años, con una estatura media de 178.8 cm y un peso promedio de 76.4 kg. La dispersión en edad y en estatura es similar a los otros clusters, pero la variabilidad en peso es un poco menor que en el Cluster 0.
#
# Al comparar los clusters, se observa una variabilidad significativa en la distribución de datos, especialmente en la edad y en el rango de estatura y peso. Mientras que la edad tiende a ser más consistente entre los clusters, la diferencia principal radica en la diversidad de estatura y peso. Los Clusters 0 y 3 muestran similitudes en términos de edad y peso, con el Cluster 0 destacándose por tener una mayor variabilidad en estatura. Por otro lado, el Cluster 1 tiene valores más bajos en estatura y peso en comparación con los otros clusters, mientras que el Cluster 2 tiene una mayor dispersión en edad y una estatura promedio similar al Cluster 3, pero con un peso ligeramente menor. Estas disparidades sugieren la existencia de diferentes subgrupos dentro de la población analizada, con variaciones distintivas en estatura, peso y, en menor medida, en edad.
#
# Se debe tener en cuenta que en este caso solamente se esta considerando las variables numéricas inicialmente solo para el análisis, pero al momento de realizar clusters se consideró las variables categóricas. Por ende, este análisis puede estar sesgado directamente por omisión de variables categóricas.

# %% [markdown]
# Luego cuando se realiza la detección de anomalías, en el grupo de datos etiquetados como Anomalías, que consta de 2,060 registros, se observa una distribución con valores notablemente más bajos en las tres variables: edad, estatura y peso normalizados. La media de estos parámetros está alrededor del 0.38 para la edad, 0.48 para la estatura y 0.41 para el peso normalizado. Estos valores son menores en comparación con el grupo de Datos No Anómalos, reflejando una tendencia general hacia mediciones más bajas en este subconjunto.
#
# La dispersión en estos parámetros, representada por las desviaciones estándar, también es más reducida en el grupo de Anomalías en comparación con el grupo de Datos No Anómalos. Además, la diferencia entre los valores mínimos y máximos es notable, siendo en general más bajos en el grupo de Anomalías. Este subgrupo parece estar caracterizado por una menor variabilidad en las mediciones de edad, estatura y peso.
#
# En contraste, el conjunto de Datos No Anómalos, compuesto por 204,092 registros, muestra valores normalizados más altos en promedio para la edad, estatura y peso. La media de estos parámetros está alrededor de 0.42 para la edad, 0.56 para la estatura y 0.47 para el peso normalizado.
#
# La dispersión en estos parámetros, como lo indica la desviación estándar, es mayor en el grupo de Datos No Anómalos en comparación con el grupo de Anomalías. También se observa una mayor variabilidad en las mediciones de edad, estatura y peso normalizado en este subgrupo en comparación con las anomalías.
#
# Al comparar ambos conjuntos, se evidencia que el grupo de Datos No Anómalos presenta valores normalizados más altos en promedio para la edad, estatura y peso, con una mayor variabilidad en estas medidas en comparación con el grupo de Anomalías, donde se registran valores notablemente más bajos y con una menor variabilidad. Este contraste sugiere una clara separación entre los dos conjuntos, donde el grupo de Anomalías muestra una tendencia hacia mediciones más bajas y menos dispersión en comparación con el grupo de Datos No Anómalos, que muestra valores normalizados más altos y una mayor variabilidad en las mediciones.

# %% [markdown]
# ### **Conclusiones**

# %% [markdown]
# Luego del desarrollo de este proyecto y del análisis exploratorio de datos, es posible notar que se logra realizar una clase que en un principio puede entregar un reporte con información relevante respecto al set de datos en el contexto de Juegos Santiago 2023 o similares. En este es posible obtener directamente información concreta de cada variable como el número de valores únicos, cantidad de anomalías, cantidad de valores negativos, además de una alerta en caso que exista algun tipo de anomalía en los datos. Adicionalmente la clase permite la limpieza de datos a través de la función clean_data, la cual permite seleccionar el método de limpieza de datos entre la eliminación de valores nulos o la imputación de estos, la eliminación de duplicados, la separación de variables no-atómicas y además permite la transformación de los datos que inicialmente vengan con un tipo predeterminado como objeto a variables ya sea tipo numérica o categórica. En el análisis quedó demostrado que este método se logró implementar de forma eficiente, transformando los datos a tipos de datos numéricos y categóricos, además de eliminar algunos de los problemas presentes al inicio de los datos, como los valores nulos, valores duplicados y presencia de valores no-atomicos, como lo fue el caso de la variable age-height-weight. También permite tratar datos donde claramente existen valores nulos que representan en si mismos a una categoría de forma implícita, como lo fue el caso de Medal, donde se logró imputar en ese caso un valor para asignar una categoría, de forma que no se perdiera información de estos datos.
# Pese a esto, los problemas indicados en el reporte como la presencia de valores Outliers no fueron tratados en esta función, puesto que estos valores deben ser revisados de forma manual para determinar si son útiles en el contexto en que se decida utilizar los datos.
#
# También se logró implementar una funcion scale que permite realizar un escalamiento y codificación de los datos numéricos y categóricos respectivamente, de forma que se genere un nuevo dataset procesado con información ya codificada, permitiendo una mejor interpretación de los datos en futuros algoritmos de aprendizaje, clusters, detección de anomalías, etc. Así fue en este caso, donde los datos debieron ser escalados y codificados para ser ingresados a algoritmos como PCA, KModes, IsolationForest, etc. Esto ayuda a que se logren suavizar los valores anómalos de tipo numéricos, al agregar una transformación logaritmica y luego MinMaxScaler.
#
# Respecto a la formación de clusters, se logró implementar un método eficiente y óptimo para la agrupación de los datos. En este caso se utilizó el método KElbowVisualizer, el cual permite optimizar el número de cluster a través del estudio del codo. Con ello, en el contexto de estos datos, fue posible identificar a través de PCA 4 grupos separados por grandes distancias, que fueron identificados eficientemente por el algoritmo de clusters KModes, aunque de igual forma existió la presencia de valores anómalos de clusters, es decir, registros que se encontraban agrupados en el análisis PCA con un conjunto de datos, pero que pertenecían a un cluster que se encontraba en una posición distante, aunque era una porción bastante baja. Cuando se realizó el análisis de cada cluster, fue posible evidenciar distintos rangos de edades, pesos y estaturas, pero que estos no eran excluyentes entre si. Es necesario destacar que para obtener una mejor caracterización de cada cluster, se recomienda considerar también para el análisis los datos categóricos. En este caso el método de clustering si utilizó los datos categóricos (ya codificados), pero para el análisis estos fueron omitidos, por lo que es muy probable que exista un tipo de sesgo por variable omitida en la caracterización de cada cluster.
#
# Adicionalmente, al implementar y aplicar la detección de anomalías, es posible apreciar la existencia de valores anómalos en cada uno de los 4 grupos obtenidos en el análisis de componentes principales de 2 dimensiones. Estos valores se encontraban espacialmente dispersos en cada uno de los 4 conjuntos, y no centrados en los extremos de cada uno como era de esperar. Esto tiene coherencia con la formación de clusters, donde existían datos que creaban clusters en conjuntos distantes aunque en pequeñas cantidades. Al observar los datos de los valores anómalos, estos corresponden a variables numéricas de bajos valores, por lo que es posible que los datos perteneciente a las colas izquierdas de las distribuciones de cada variable sean outliers que esten afectando a la generación de clusters eficientes, y que permitan una mejor caracterización de conjuntos de datos.
#
# Finalmente, luego de la implementación de esta clase y de todo el análisis realizado, es posible afirmar que se logró desarrollar un modelo eficiente para la caracterización automática de los datos, que adicionalmente permite realizar un correcto análisis de los datos para solucionar algun problema posible respecto a la caracterización. En este caso, a priori no es posible realizar una caracterización 100% fidedigna, puesto que como se observó en los clusters y detección de anomalías, existes valores que pueden estar perjudicando al caracterización automática, sin embargo, a través de una exploración de los datos es posible identificar estos posibles problemas y tomar una decisión de que hacer con los datos identificados como problemáticos. También es necesario mencionar que en este análisis se incorporaron solamente algunos modelos para realizar clusters, detectar anomalías, realizar escalamiento de los datos, codificaciones, etc. Pero pese a esto, la clase implementada permite la modificación de estos modelos al ser ingresados como variables de entrada. Por ende, la solución propuesta es un buen camino para lograr una caracterización mucho mas robusta, pero que de momento presenta resultados suficientes y esperanzadores.
